# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath = 'Documents/creditcard.csv'
data = pd.read_csv(filepath)
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.isnull().values.any()
# Out:
# False

# %%
count_classes = pd.value_counts(data['Class'])
count_classes
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
count_classes.plot(kind = 'bar', rot=0)  #rotation = 0

plt.title("Distribution of Transaction Class")
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Getting the fraud and normal datasets

fraud = data[data['Class']==1]

normal = data[data['Class']==0]

print(fraud.shape, normal.shape)
# Out:
# (492, 31) (284315, 31)

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
#Taking some sample of our data.

data1 = data.sample(frac = 0.1, random_state = 42)
data1.shape
# Out:
# (28481, 31)

# %%
fraud_in_sample = data1[data1['Class']==1]
valid_in_sample = data1[data1['Class']==0]

outlier_fraction = len(fraud_in_sample)/float(len(valid_in_sample))

# %%
outlier_fraction
# Out:
# 0.001617724635132759

# %%
print(len(fraud_in_sample), len(valid_in_sample))
# Out:
# 46 28435

# %%
corrmat = data1.corr()
corr_features = corrmat.index

plt.figure(figsize=(30,30))

g = sns.heatmap(data[corr_features].corr(), annot=True)

# %%
#Defining our features as x and target as y.
features = [c for c in data1.columns if c!="Class"]
target = "Class"
x = data1[features]
y = data1[target]

# %%
print(x.shape, y.shape)
# Out:
# (28481, 30) (28481,)

# %%
data1[target].value_counts(normalize=True)
# Out:
# 0    0.998385
# 1    0.001615
# Name: Class, dtype: float64

# %%
from sklearn.model_selection import train_test_split   #performing train test split within our train dataset taking 70% as train and 30% as test features and target.

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42, stratify=y)

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.998395
# 1    0.001605
# Name: Class, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.998362
# 1    0.001638
# Name: Class, dtype: float64

# %%
#now we will do random forest, set the optimal no of trees and see the errors as well.
from sklearn.ensemble import RandomForestClassifier

# Initialize the random forest estimator
# Note that the number of trees is not setup here
RF = RandomForestClassifier(oob_score=True,    #out of bag score
                            random_state=42, 
                            warm_start=True,
                            n_jobs=-1)
#now we wanna check every out of bags errors.
oob_list = list()

# Iterate through all of the possibilities for 
# number of trees
for n_trees in [15, 20, 30, 40, 50, 100, 150, 200, 300, 400]:
    
    # Use this to set the number of trees
    RF.set_params(n_estimators=n_trees)

    # Fit the model
    RF.fit(x_train, y_train)

    # Get the oob error
    oob_error = 1 - RF.oob_score_  #this is a attribute available within rf, if you set oob = true
    
    # Store it
    oob_list.append(pd.Series({'n_trees': n_trees, 'oob': oob_error}))

rf_oob_df = pd.concat(oob_list, axis=1).T.set_index('n_trees')

rf_oob_df
# Out:
# C:\Users\agent\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:541: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\agent\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:545: RuntimeWarning: invalid value encountered in true_divide
#   decision = (predictions[k] /
# C:\Users\agent\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:541: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\agent\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:545: RuntimeWarning: invalid value encountered in true_divide
#   decision = (predictions[k] /
#               oob
# n_trees
# 15.0     0.001154
# 20.0     0.001053
# 30.0     0.000953
# 40.0     0.000953
# 50.0     0.000903
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set_context('talk')
sns.set_style('white')

ax = rf_oob_df.plot(legend=False, marker='o', figsize=(14, 7), linewidth=5)
ax.set(ylabel='out-of-bag error');

#we can see drop off in error, and it's low at around 40 and it seems to somewhat go down untill 50

# %%
model = RF.set_params(n_estimators=40) #as it did well on 40 trees, from that number of trees it's showing a downward trend

y_pred = model.predict(x_test)

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8531
#            1       0.92      0.86      0.89        14
#
#     accuracy                           1.00      8545
#    macro avg       0.96      0.93      0.94      8545
# weighted avg       1.00      1.00      1.00      8545

# %%
print("Accuracy Score :")
print(accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score :
# 0.9996489174956115

# %%
#define the outlier detection methods.
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
classifiers = {
   "Isolation Forest": IsolationForest(n_estimators=100, max_samples = len(x), 
                                      contamination=outlier_fraction, random_state=42, verbose=0),
  
    "Support Vector Machine" : OneClassSVM(kernel='rbf', degree=3, gamma=0.1, nu=0.05, max_iter=-1)
  
}

# %%
n_outliers = len(fraud_in_sample)


for i, (clf_name,clf) in enumerate(classifiers.items()):
    #Fit the data and tag outliers
    
    if clf_name == "Support Vector Machine":
        clf.fit(x)
        y_pred = clf.predict(x)
    else:    
        clf.fit(x)
        scores_prediction = clf.decision_function(x)
        y_pred = clf.predict(x)
    #Reshape the prediction values to 0 for Valid transactions , 1 for Fraud transactions
    y_pred[y_pred == 1] = 0
    y_pred[y_pred == -1] = 1
    n_errors = (y_pred != y).sum()
    # Run Classification Metrics
    print("{}: {}".format(clf_name,n_errors))
    print("Accuracy Score :")
    print(accuracy_score(y,y_pred))
    print("Classification Report :")
    print(classification_report(y,y_pred))
# Out:
# Isolation Forest: 63
# Accuracy Score :
# 0.9977879990168884
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28435
#            1       0.32      0.33      0.32        46
#
#     accuracy                           1.00     28481
#    macro avg       0.66      0.66      0.66     28481
# weighted avg       1.00      1.00      1.00     28481
#
# Support Vector Machine: 9526
# Accuracy Score :
# 0.6655314069028475
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80     28435
#            1       0.00      0.28      0.00        46
#
#     accuracy                           0.67     28481
#    macro avg       0.50      0.47      0.40     28481
# weighted avg       1.00      0.67      0.80     28481
